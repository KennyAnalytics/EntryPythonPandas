# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('modified.csv')

# %%
# Filtering out the dataset so that it shows only the mega pokemon. 
# I should just make a new csv file instead of making a new df for it.
df.loc[df['Name'].str.contains('Mega ')].head(5)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 12   9    BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 19  15      BeedrillMega Beedrill    Bug  Poison    495  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3       122      120     80           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 12      135      115     78           1      False
# 19       15       80    145           1      False

# %%
df.loc[df['Name'].str.contains('Mega ')].count()
# Out:
# #             48
# Name          48
# Type 1        48
# Type 2        39
# Total         48
# HP            48
# Attack        48
# Defense       48
# Sp. Atk       48
# Sp. Def       48
# Speed         48
# Generation    48
# Legendary     48
# dtype: int64

# %%
mega=df.loc[(df['Name'].str.contains('Mega '))|(df['Name'].str.contains('Primal '))]
mega.head(5)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 12   9    BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 19  15      BeedrillMega Beedrill    Bug  Poison    495  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3       122      120     80           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 12      135      115     78           1      False
# 19       15       80    145           1      False

# %%
mega.count()
# Out:
# #             50
# Name          50
# Type 1        50
# Type 2        40
# Total         50
# HP            50
# Attack        50
# Defense       50
# Sp. Atk       50
# Sp. Def       50
# Speed         50
# Generation    50
# Legendary     50
# dtype: int64

# %% [markdown]
# mega.describe()

# %%
mega.sort_values(by=['Total'], ascending=False).head(5)
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 164       70      194      120    140           1       True
# 163      100      154      100    130           1       True
# 426      100      180      100    115           3       True
# 424      160      150       90     90           3       True
# 422       90      180      160     90           3       True

# %%
mega[mega['Total'] > 700]
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 422  382    KyogrePrimal Kyogre    Water       NaN    770  100     150
# 424  383  GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      100      154      100    130           1       True
# 164       70      194      120    140           1       True
# 422       90      180      160     90           3       True
# 424      160      150       90     90           3       True
# 426      100      180      100    115           3       True

# %%
mega['Total'] > 700
# Out:
# 3      False
# 7      False
# 8      False
# 12     False
# 19     False
# 23     False
# 71     False
# 87     False
# 102    False
# 124    False
# 137    False
# 141    False
# 154    False
# 163     True
# 164     True
# 196    False
# 224    False
# 229    False
# 232    False
# 248    False
# 268    False
# 275    False
# 279    False
# 283    False
# 306    False
# 327    False
# 329    False
# 333    False
# 336    False
# 339    False
# 349    False
# 354    False
# 366    False
# 387    False
# 393    False
# 397    False
# 409    False
# 413    False
# 418    False
# 420    False
# 422     True
# 424     True
# 426     True
# 476    False
# 494    False
# 498    False
# 511    False
# 527    False
# 591    False
# 796    False
# Name: Total, dtype: bool

# %%
mega.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 3 to 796
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           50 non-null     int64
#  1   Name        50 non-null     object
#  2   Type 1      50 non-null     object
#  3   Type 2      40 non-null     object
#  4   Total       50 non-null     int64
#  5   HP          50 non-null     int64
#  6   Attack      50 non-null     int64
#  7   Defense     50 non-null     int64
#  8   Sp. Atk     50 non-null     int64
#  9   Sp. Def     50 non-null     int64
#  10  Speed       50 non-null     int64
#  11  Generation  50 non-null     int64
#  12  Legendary   50 non-null     bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 5.1+ KB

# %%
mega.sort_values(by=['Sp. Atk'], ascending=[False]).head(5)
# Out:
#        #                   Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 164  150    MewtwoMega Mewtwo Y  Psychic     NaN    780  106     150       70
# 422  382    KyogrePrimal Kyogre    Water     NaN    770  100     150       90
# 426  384  RayquazaMega Rayquaza   Dragon  Flying    780  105     180      100
# 71    65  AlakazamMega Alakazam  Psychic     NaN    590   55      50       65
# 102   94      GengarMega Gengar    Ghost  Poison    600   60      65       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 164      194      120    140           1       True
# 422      180      160     90           3       True
# 426      180      100    115           3       True
# 71       175       95    150           1      False
# 102      170       95    130           1      False

# %%
mega.query('Attack > (Speed)')
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# 141  130      GyaradosMega Gyarados     Water      Dark    640   95     155
# 163  150        MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 164  150        MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# ...

# %%
mega.index
# Out:
# Int64Index([  3,   7,   8,  12,  19,  23,  71,  87, 102, 124, 137, 141, 154,
#             163, 164, 196, 224, 229, 232, 248, 268, 275, 279, 283, 306, 327,
#             329, 333, 336, 339, 349, 354, 366, 387, 393, 397, 409, 413, 418,
#             420, 422, 424, 426, 476, 494, 498, 511, 527, 591, 796],
#            dtype='int64')

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
mega.sort_values(['Total']), ascending=[False]
# Out:
#   File "C:\Users\kenny\AppData\Local\Temp\ipykernel_25840\1214545242.py", line 1
#     mega.sort_values(['Total']), ascending=[False]
#     ^
# SyntaxError: cannot assign to function call

# %%
df_sample.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24300\1108943092.py in <module>
# ----> 1 df_sample.plot()
#
# NameError: name 'df_sample' is not defined

# %%
mega.plot()
# Out:
# <AxesSubplot:>

# %%
mega.plot(x='#', y='Total')
# Out:
# <AxesSubplot:xlabel='#'>

# %%
mega.to_csv('mega.csv', index=False)
